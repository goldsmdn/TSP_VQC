# %% [markdown]
# # Test graph connectivity
#
# Ensure that the Rigetti qubit connectivities are valid.

# %%
from modules.config import VALID_QUBIT_LOOPS
from modules.AWS_helper_functions_tsp import validate_qubit_loops

# %%
#import os
#os.environ.get("AWS_PROFILE")
# Out:
# 'qcap'

# %%
#import boto3

#sts = boto3.client("sts")
#sts.get_caller_identity()
# Out:
# {'UserId': 'AROAW3IJGW7YWY4NR4FI5:d.goldsmith@kingston.ac.uk',
#  'Account': '470855104497',
#  'Arn': 'arn:aws:sts::470855104497:assumed-role/AWSReservedSSO_SparQ_Academic_Researcher_982c89a6a038c733/d.goldsmith@kingston.ac.uk',
#  'ResponseMetadata': {'RequestId': '4fb2ff20-cbb3-4cb3-b7b4-5757d5ce94c4',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '4fb2ff20-cbb3-4cb3-b7b4-5757d5ce94c4',
#    'x-amz-sts-extended-request-id': 'MTpldS13ZXN0LTI6UzoxNzc4NTI0MTAxMzI5OlI6WTZnRFc0dHQ=',
#    'content-type': 'text/xml',
#    'content-length': '516',
#    'date': 'Mon, 11 May 2026 18:28:21 GMT'},
#   'RetryAttempts': 0}}

# %%
for target in ['cephus']:
    for i in [3, 8, 14, 29, 41, 49,]:
        validate_qubit_loops(i, VALID_QUBIT_LOOPS, target)
# Out:
# No errors found for target='cephus' qubits=3
#
# No errors found for target='cephus' qubits=8
#
# No errors found for target='cephus' qubits=14
#
# No errors found for target='cephus' qubits=29
#
# No errors found for target='cephus' qubits=41
#
# No errors found for target='cephus' qubits=49
