# %%
#test

# %%
from modules.helper_functions_tsp import(
    validate_distance_array, find_distance, convert_binary_list_to_integer, 
    check_loc_list, augment_loc_list, find_total_distance, find_problem_size,
    convert_bit_string_to_cycle, find_stats, cost_fn_fact, hot_start,
    hot_start_list_to_string, convert_integer_to_binary_list,
    convert_binary_list_to_integer)

# %%
locs = 4
method = 'new'
gray = False
dim = find_problem_size(locs, method=method)
expected_result = []
actual_result = []
integer = 6
binary_list = convert_integer_to_binary_list(integer, dim, gray=gray)
cycle = convert_bit_string_to_cycle(binary_list, locs, gray=gray, method=method)
new_binary_list = hot_start_list_to_string(cycle, locs, gray=gray, method=method)
print(binary_list, new_binary_list  )
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[7], line 10
#       8 binary_list = convert_integer_to_binary_list(integer, dim, gray=False)
#       9 cycle = convert_bit_string_to_cycle(binary_list, locs, gray=gray, method=method)
# ---> 10 new_binary_list = hot_start_list_to_string(cycle, locs, gray)
#      11 print(binary_list, new_binary_list  )
#
# File c:\Users\DanielGoldsmith\python notebooks\TSP_VQC\modules\helper_functions_tsp.py:555, in hot_start_list_to_string(hot_start_list, locations, gray, method)
#     553 #remove the first item for the list which should be zero
#     554 if first_item != 0:
# --> 555     raise Exception(f'The first item of the list must be zero')
#     557 initial_list = [i for i in range(1, locations)]
#     558 total_binary_string = ''
#
# Exception: The first item of the list must be zero
