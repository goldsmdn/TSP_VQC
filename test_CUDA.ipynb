# %%
# Test CUDA
import torch

print("Torch version:", torch.__version__)
print("Built with CUDA:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU detected:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.7.1+cu118
# Built with CUDA: 11.8
# CUDA available: True
# GPU detected: NVIDIA GeForce GTX 1650

# %%
x = torch.randn(3, 3).cuda()
print("Tensor on GPU:\n", x)
# Out:
# Tensor on GPU:
#  tensor([[-0.1744,  0.5407,  0.8527],
#         [-2.2431,  0.2907,  0.7746],
#         [ 0.4586,  0.2062,  0.1897]], device='cuda:0')

# %%
# Select NVIDIA GPU explicitly
device = torch.device("cuda:0")  # 0 is usually your NVIDIA GPU
x = torch.randn(5, 5).to(device)

print(x.device)
# Out:
# cuda:0

# %%
for i in range(torch.cuda.device_count()):
    print(i, torch.cuda.get_device_name(i))
# Out:
# 0 NVIDIA GeForce GTX 1650
